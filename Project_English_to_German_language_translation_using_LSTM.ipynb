# %% [markdown]
# <a href="https://colab.research.google.com/github/MiteshNagothkar/AI_Project/blob/main/Project_English_to_German_language_translation_using_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense

# %%
# Dummy dataset (replace with your actual data)
input_texts = ['Hello', 'How are you?', 'Goodbye']
target_texts = ['Hallo', 'Wie geht es dir?', 'Auf Wiedersehen']

# %%
# Tokenization and vocabulary creation
input_vocab = set(' '.join(input_texts))
target_vocab = set(' '.join(target_texts))

input_token_index = dict((c, i) for i, c in enumerate(input_vocab))
target_token_index = dict((c, i) for i, c in enumerate(target_vocab))

num_encoder_tokens = len(input_vocab)
num_decoder_tokens = len(target_vocab)

max_encoder_seq_length = max(len(seq) for seq in input_texts)
max_decoder_seq_length = max(len(seq) for seq in target_texts)

# %%
# Data preprocessing
encoder_input_data = np.zeros((len(input_texts), max_encoder_seq_length, num_encoder_tokens), dtype='float32')
decoder_input_data = np.zeros((len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype='float32')
decoder_target_data = np.zeros((len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype='float32')

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.0
    for t, char in enumerate(target_text):
        decoder_input_data[i, t, target_token_index[char]] = 1.0
        if t > 0:
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.0

# %%
# Define the model
latent_dim = 256

encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)
encoder_states = [state_h, state_c]

decoder_inputs = Input(shape=(None, num_decoder_tokens))
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
# Compile and train the model
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit([encoder_input_data, decoder_input_data], decoder_target_data, epochs=100, batch_size=1, validation_split=0.2)
# Use the trained model for inference
encoder_model = Model(encoder_inputs, encoder_states)

decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

decoder_outputs, state_h, state_c = decoder_lstm(decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)

decoder_model = Model([decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states)

# Add the end-of-sequence token to the target_token_index
target_token_index['\n'] = len(target_token_index)

def translate_sentence(input_sentence):
    input_seq = np.zeros((1, max_encoder_seq_length, num_encoder_tokens))
    for t, char in enumerate(input_sentence):
        input_seq[0, t, input_token_index[char]] = 1.0

    states_value = encoder_model.predict(input_seq)

    # Find the actual start-of-sequence token in your dataset
    start_token = '\t' if '\t' in target_token_index else list(target_token_index.keys())[0]
    end_token = '\n'    # Use the correct end-of-sequence token

    target_seq = np.zeros((1, 1, num_decoder_tokens))
    target_seq[0, 0, target_token_index[start_token]] = 1.0

    translated_sentence = ''
    stop_condition = False
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = [char for char, index in target_token_index.items() if index == sampled_token_index][0]
        translated_sentence += sampled_char

        if sampled_char == end_token or len(translated_sentence) > max_decoder_seq_length:
            stop_condition = True

        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.0

        states_value = [h, c]

    return translated_sentence
# Out:
# Epoch 1/100
# 2/2 [==============================] - 4s 924ms/step - loss: 1.7524 - accuracy: 0.0625 - val_loss: 2.5649 - val_accuracy: 0.1875
# Epoch 2/100
# 2/2 [==============================] - 0s 62ms/step - loss: 1.7224 - accuracy: 0.1875 - val_loss: 2.5501 - val_accuracy: 0.1250
# Epoch 3/100
# 2/2 [==============================] - 0s 65ms/step - loss: 1.6957 - accuracy: 0.1875 - val_loss: 2.5286 - val_accuracy: 0.1250
# Epoch 4/100
# 2/2 [==============================] - 0s 63ms/step - loss: 1.6634 - accuracy: 0.1250 - val_loss: 2.4866 - val_accuracy: 0.2500
# Epoch 5/100
# 2/2 [==============================] - 0s 78ms/step - loss: 1.5963 - accuracy: 0.1250 - val_loss: 2.3899 - val_accuracy: 0.2500
# Epoch 6/100
# 2/2 [==============================] - 0s 65ms/step - loss: 1.5087 - accuracy: 0.0938 - val_loss: 2.4799 - val_accuracy: 0.0000e+00
# Epoch 7/100
# 2/2 [==============================] - 0s 74ms/step - loss: 1.4487 - accuracy: 0.1562 - val_loss: 2.4833 - val_accuracy: 0.0625
# Epoch 8/100
# 2/2 [==============================] - 0s 57ms/step - loss: 1.3773 - accuracy: 0.1250 - val_loss: 2.6193 - val_accuracy: 0.0625
# Epoch 9/100
# 2/2 [==============================] - 0s 64ms/step - loss: 1.3735 - accuracy: 0.0938 - val_loss: 2.6511 - val_accuracy: 0.0625
# Epoch 10/100
# 2/2 [==============================] - 0s 60ms/step - loss: 1.3294 - accuracy: 0.1562 - val_loss: 2.7238 - val_accuracy: 0.2500
# Epoch 11/100
# 2/2 [==============================] - 0s 75ms/step - loss: 1.3079 - accuracy: 0.0625 - val_loss: 2.7991 - val_accuracy: 0.2500
# Epoch 12/100
# 2/2 [==============================] - 0s 63ms/step - loss: 1.2998 - accuracy: 0.1250 - val_loss: 2.8419 - val_accuracy: 0.0000e+00
# Epoch 13/100
# 2/2 [==============================] - 0s 60ms/step - loss: 1.3102 - accuracy: 0.0625 - val_loss: 2.9208 - val_accuracy: 0.0000e+00
# Epoch 14/100
# 2/2 [==============================] - 0s 72ms/step - loss: 1.2635 - accuracy: 0.0938 - val_loss: 2.9444 - val_accuracy: 0.0625
# Epoch 15/100
# 2/2 [==============================] - 0s 65ms/step - loss: 1.2390 - accuracy: 0.1562 - val_loss: 3.0059 - val_accuracy: 0.0625
# Epoch 16/100
# 2/2 [==============================] - 0s 63ms/step - loss: 1.2201 - accuracy: 0.1250 - val_loss: 2.9821 - val_accuracy: 0.0625
# Epoch 17/100
# 2/2 [==============================] - 0s 92ms/step - loss: 1.2112 - accuracy: 0.1250 - val_loss: 3.0722 - val_accuracy: 0.0625
# Epoch 18/100
# 2/2 [==============================] - 0s 68ms/step - loss: 1.1307 - accuracy: 0.1562 - val_loss: 3.0046 - val_accuracy: 0.0000e+00
# Epoch 19/100
# 2/2 [==============================] - 0s 65ms/step - loss: 1.2193 - accuracy: 0.1562 - val_loss: 3.1014 - val_accuracy: 0.0000e+00
# Epoch 20/100
# 2/2 [==============================] - 0s 59ms/step - loss: 1.1612 - accuracy: 0.1875 - val_loss: 3.1577 - val_accuracy: 0.0625
# Epoch 21/100
# 2/2 [==============================] - 0s 63ms/step - loss: 1.1443 - accuracy: 0.1562 - val_loss: 3.1514 - val_accuracy: 0.0000e+00
# Epoch 22/100
# 2/2 [==============================] - 0s 61ms/step - loss: 1.1055 - accuracy: 0.1875 - val_loss: 3.1387 - val_accuracy: 0.0000e+00
# Epoch 23/100
# 2/2 [==============================] - 0s 71ms/step - loss: 1.1458 - accuracy: 0.1562 - val_loss: 3.1827 - val_accuracy: 0.0000e+00
# Epoch 24/100
# 2/2 [==============================] - 0s 60ms/step - loss: 1.1328 - accuracy: 0.1875 - val_loss: 3.2759 - val_accuracy: 0.0000e+00
# Epoch 25/100
# 2/2 [==============================] - 0s 63ms/step - loss: 1.1193 - accuracy: 0.1875 - val_loss: 3.2754 - val_accuracy: 0.0000e+00
# Epoch 26/100
# 2/2 [==============================] - 0s 72ms/step - loss: 1.1111 - accuracy: 0.1875 - val_loss: 3.2331 - val_accuracy: 0.0625
# Epoch 27/100
# 2/2 [==============================] - 0s 75ms/step - loss: 1.0516 - accuracy: 0.2188 - val_loss: 3.1825 - val_accuracy: 0.0625
# Epoch 28/100
# 2/2 [==============================] - 0s 62ms/step - loss: 1.1447 - accuracy: 0.1562 - val_loss: 3.2599 - val_accuracy: 0.0625
# Epoch 29/100
# 2/2 [==============================] - 0s 57ms/step - loss: 1.0850 - accuracy: 0.1875 - val_loss: 3.3362 - val_accuracy: 0.0000e+00
# Epoch 30/100
# 2/2 [==============================] - 0s 59ms/step - loss: 1.0702 - accuracy: 0.1875 - val_loss: 3.3646 - val_accuracy: 0.0000e+00
# Epoch 31/100
# 2/2 [==============================] - 0s 59ms/step - loss: 1.0590 - accuracy: 0.1875 - val_loss: 3.3477 - val_accuracy: 0.0625
# Epoch 32/100
# 2/2 [==============================] - 0s 62ms/step - loss: 1.0663 - accuracy: 0.1875 - val_loss: 3.3427 - val_accuracy: 0.0625
# Epoch 33/100
# 2/2 [==============================] - 0s 63ms/step - loss: 1.0652 - accuracy: 0.1562 - val_loss: 3.3815 - val_accuracy: 0.0625
# Epoch 34/100
# 2/2 [==============================] - 0s 64ms/step - loss: 1.0019 - accuracy: 0.2188 - val_loss: 3.2199 - val_accuracy: 0.0000e+00
# Epoch 35/100
# 2/2 [==============================] - 0s 84ms/step - loss: 1.0989 - accuracy: 0.1562 - val_loss: 3.4111 - val_accuracy: 0.0000e+00
# Epoch 36/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.9972 - accuracy: 0.2188 - val_loss: 3.2929 - val_accuracy: 0.0000e+00
# Epoch 37/100
# 2/2 [==============================] - 0s 62ms/step - loss: 1.0498 - accuracy: 0.1875 - val_loss: 3.4798 - val_accuracy: 0.0625
# Epoch 38/100
# 2/2 [==============================] - 0s 93ms/step - loss: 1.0352 - accuracy: 0.2188 - val_loss: 3.4569 - val_accuracy: 0.0000e+00
# Epoch 39/100
# 2/2 [==============================] - 0s 111ms/step - loss: 1.0144 - accuracy: 0.2188 - val_loss: 3.4087 - val_accuracy: 0.0625
# Epoch 40/100
# 2/2 [==============================] - 0s 100ms/step - loss: 1.0232 - accuracy: 0.2500 - val_loss: 3.4234 - val_accuracy: 0.1250
# Epoch 41/100
# 2/2 [==============================] - 0s 101ms/step - loss: 0.9485 - accuracy: 0.2500 - val_loss: 3.2236 - val_accuracy: 0.0000e+00
# Epoch 42/100
# 2/2 [==============================] - 0s 101ms/step - loss: 0.9763 - accuracy: 0.3125 - val_loss: 3.4504 - val_accuracy: 0.0000e+00
# Epoch 43/100
# 2/2 [==============================] - 0s 95ms/step - loss: 0.9652 - accuracy: 0.2812 - val_loss: 3.5013 - val_accuracy: 0.0625
# Epoch 44/100
# 2/2 [==============================] - 0s 106ms/step - loss: 0.9436 - accuracy: 0.2812 - val_loss: 3.3347 - val_accuracy: 0.0000e+00
# Epoch 45/100
# 2/2 [==============================] - 0s 102ms/step - loss: 0.9144 - accuracy: 0.3125 - val_loss: 3.6830 - val_accuracy: 0.1250
# Epoch 46/100
# 2/2 [==============================] - 0s 107ms/step - loss: 0.9802 - accuracy: 0.2500 - val_loss: 3.6507 - val_accuracy: 0.1250
# Epoch 47/100
# 2/2 [==============================] - 0s 87ms/step - loss: 0.9278 - accuracy: 0.2812 - val_loss: 3.6821 - val_accuracy: 0.1250
# Epoch 48/100
# 2/2 [==============================] - 0s 99ms/step - loss: 0.8692 - accuracy: 0.3438 - val_loss: 3.6252 - val_accuracy: 0.0625
# Epoch 49/100
# 2/2 [==============================] - 0s 119ms/step - loss: 0.8485 - accuracy: 0.3125 - val_loss: 3.5321 - val_accuracy: 0.0000e+00
# Epoch 50/100
# 2/2 [==============================] - 0s 110ms/step - loss: 0.8702 - accuracy: 0.3438 - val_loss: 3.8976 - val_accuracy: 0.1250
# Epoch 51/100
# 2/2 [==============================] - 0s 127ms/step - loss: 0.8169 - accuracy: 0.3125 - val_loss: 3.5916 - val_accuracy: 0.0625
# Epoch 52/100
# 2/2 [==============================] - 0s 120ms/step - loss: 0.8826 - accuracy: 0.2812 - val_loss: 3.4708 - val_accuracy: 0.0000e+00
# Epoch 53/100
# 2/2 [==============================] - 0s 122ms/step - loss: 0.9489 - accuracy: 0.2812 - val_loss: 3.6252 - val_accuracy: 0.0000e+00
# Epoch 54/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.7717 - accuracy: 0.3125 - val_loss: 3.6639 - val_accuracy: 0.0625
# Epoch 55/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.7798 - accuracy: 0.2812 - val_loss: 3.6395 - val_accuracy: 0.0000e+00
# Epoch 56/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.7536 - accuracy: 0.3125 - val_loss: 3.7404 - val_accuracy: 0.1250
# Epoch 57/100
# 2/2 [==============================] - 0s 75ms/step - loss: 0.7500 - accuracy: 0.2812 - val_loss: 3.6238 - val_accuracy: 0.0000e+00
# Epoch 58/100
# 2/2 [==============================] - 0s 69ms/step - loss: 0.7681 - accuracy: 0.3750 - val_loss: 3.9664 - val_accuracy: 0.0625
# Epoch 59/100
# 2/2 [==============================] - 0s 78ms/step - loss: 0.8761 - accuracy: 0.2188 - val_loss: 3.6241 - val_accuracy: 0.0000e+00
# Epoch 60/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.8833 - accuracy: 0.2812 - val_loss: 3.7718 - val_accuracy: 0.1250
# Epoch 61/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.7673 - accuracy: 0.3438 - val_loss: 3.8679 - val_accuracy: 0.1250
# Epoch 62/100
# 2/2 [==============================] - 0s 79ms/step - loss: 0.7254 - accuracy: 0.2812 - val_loss: 3.6894 - val_accuracy: 0.0000e+00
# Epoch 63/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.7287 - accuracy: 0.3750 - val_loss: 3.6912 - val_accuracy: 0.0625
# Epoch 64/100
# 2/2 [==============================] - 0s 74ms/step - loss: 0.7462 - accuracy: 0.2812 - val_loss: 3.7718 - val_accuracy: 0.0000e+00
# Epoch 65/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.7178 - accuracy: 0.3750 - val_loss: 3.9713 - val_accuracy: 0.1250
# Epoch 66/100
# 2/2 [==============================] - 0s 78ms/step - loss: 0.8234 - accuracy: 0.2188 - val_loss: 3.6757 - val_accuracy: 0.0000e+00
# Epoch 67/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.7929 - accuracy: 0.3438 - val_loss: 3.8469 - val_accuracy: 0.1250
# Epoch 68/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.6970 - accuracy: 0.3125 - val_loss: 3.7969 - val_accuracy: 0.1250
# Epoch 69/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.6956 - accuracy: 0.4062 - val_loss: 3.9677 - val_accuracy: 0.0625
# Epoch 70/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.7152 - accuracy: 0.2812 - val_loss: 3.8078 - val_accuracy: 0.0000e+00
# Epoch 71/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.7250 - accuracy: 0.3438 - val_loss: 3.8574 - val_accuracy: 0.1250
# Epoch 72/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.7611 - accuracy: 0.3125 - val_loss: 3.8459 - val_accuracy: 0.1250
# Epoch 73/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.6880 - accuracy: 0.3750 - val_loss: 3.9037 - val_accuracy: 0.1250
# Epoch 74/100
# 2/2 [==============================] - 0s 69ms/step - loss: 0.6671 - accuracy: 0.3750 - val_loss: 3.9668 - val_accuracy: 0.1250
# Epoch 75/100
# 2/2 [==============================] - 0s 68ms/step - loss: 0.6643 - accuracy: 0.3750 - val_loss: 3.9280 - val_accuracy: 0.1250
# Epoch 76/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.6544 - accuracy: 0.3750 - val_loss: 3.8837 - val_accuracy: 0.1250
# Epoch 77/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.6792 - accuracy: 0.4062 - val_loss: 3.9642 - val_accuracy: 0.0000e+00
# Epoch 78/100
# 2/2 [==============================] - 0s 85ms/step - loss: 0.7184 - accuracy: 0.2812 - val_loss: 3.8357 - val_accuracy: 0.0000e+00
# Epoch 79/100
# 2/2 [==============================] - 0s 73ms/step - loss: 0.9316 - accuracy: 0.3125 - val_loss: 4.0137 - val_accuracy: 0.1250
# Epoch 80/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.6582 - accuracy: 0.3438 - val_loss: 4.0461 - val_accuracy: 0.1250
# Epoch 81/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.6944 - accuracy: 0.3750 - val_loss: 4.0659 - val_accuracy: 0.0625
# Epoch 82/100
# 2/2 [==============================] - 0s 84ms/step - loss: 0.6456 - accuracy: 0.4062 - val_loss: 4.1370 - val_accuracy: 0.0625
# Epoch 83/100
# 2/2 [==============================] - 0s 70ms/step - loss: 0.6779 - accuracy: 0.3125 - val_loss: 3.9293 - val_accuracy: 0.0625
# Epoch 84/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.7038 - accuracy: 0.3438 - val_loss: 4.1695 - val_accuracy: 0.1250
# Epoch 85/100
# 2/2 [==============================] - 0s 83ms/step - loss: 0.6440 - accuracy: 0.3438 - val_loss: 3.9725 - val_accuracy: 0.1250
# Epoch 86/100
# 2/2 [==============================] - 0s 80ms/step - loss: 0.6906 - accuracy: 0.3750 - val_loss: 4.2142 - val_accuracy: 0.1250
# Epoch 87/100
# 2/2 [==============================] - 0s 75ms/step - loss: 0.6939 - accuracy: 0.2812 - val_loss: 3.9174 - val_accuracy: 0.0000e+00
# Epoch 88/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.7474 - accuracy: 0.3438 - val_loss: 4.1078 - val_accuracy: 0.0625
# Epoch 89/100
# 2/2 [==============================] - 0s 75ms/step - loss: 0.6359 - accuracy: 0.4062 - val_loss: 4.1025 - val_accuracy: 0.0625
# Epoch 90/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.6821 - accuracy: 0.3438 - val_loss: 4.0451 - val_accuracy: 0.1250
# Epoch 91/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.6328 - accuracy: 0.4062 - val_loss: 4.1590 - val_accuracy: 0.0625
# Epoch 92/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.6428 - accuracy: 0.3438 - val_loss: 3.9713 - val_accuracy: 0.1250
# Epoch 93/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.6557 - accuracy: 0.3750 - val_loss: 4.1985 - val_accuracy: 0.0625
# Epoch 94/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.6231 - accuracy: 0.3438 - val_loss: 4.0174 - val_accuracy: 0.1250
# Epoch 95/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.6603 - accuracy: 0.4062 - val_loss: 4.2803 - val_accuracy: 0.1250
# Epoch 96/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.6789 - accuracy: 0.2812 - val_loss: 3.8975 - val_accuracy: 0.0625
# Epoch 97/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.7026 - accuracy: 0.3438 - val_loss: 4.0458 - val_accuracy: 0.0625
# Epoch 98/100
# 2/2 [==============================] - 0s 68ms/step - loss: 0.6539 - accuracy: 0.3750 - val_loss: 4.1181 - val_accuracy: 0.0625
# Epoch 99/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.6051 - accuracy: 0.3750 - val_loss: 4.1806 - val_accuracy: 0.0625
# Epoch 100/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.6377 - accuracy: 0.3750 - val_loss: 4.1828 - val_accuracy: 0.0625
